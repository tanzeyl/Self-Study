# %% [markdown]
# <a href="https://colab.research.google.com/github/tanzeyl/Self-Study/blob/main/Python_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
list1 = [2,4,6,1]
plt.plot(list1)
plt.ylabel("Values")
plt.xlabel("Indices")
plt.title("My Plot")
plt.grid()

# %%
list1 =[1,2,3,4,5,6]
list2 = [1,4,9,16,25,36]
plt.plot(list1, list2, 'go')

# %%
import numpy as np
t = np.arange(0, 5, 0.2)
plt.plot(t, t**2, "b--", label = " ^2")
plt.plot(t, t**2.2, "rs", label = " ^2.2")
plt.plot(t, t**2.5, "g^", label = " ^2.5")
plt.legend()
plt.grid()

# %%
x1 = [1,2,3,4]
y1 = [1,4,9,16]
x2 = [1,2,3,4]
y2 = [1,4,6,8]
lines = plt.plot(x1,y1,x2,y2)
plt.setp(lines[0], color = 'r', linewidth = 2)
plt.setp(lines[1], color = 'y', linewidth = 2)
# Out:
# [None, None]

# %%
def f(t):
  return np.exp(-t) * np.cos(2*np.pi*t)
t1 = np.arange(0,100,2)
t2 = np.arange(0,700,3)
plt.figure(1)
plt.subplot(211)
plt.grid()
plt.plot(t1, f(t1), 'b--')
plt.subplot(212)
plt.grid()
plt.plot(t2, f(t2), 'r--')

# %%
import pandas as pd
# Creating your own data frame
info = [("Tanzeel Khan", "05/05/2001", "Kanpur",20),
           ("Khizra Khan", "10'06'2002", "Allahabad", 19),
            ("Atiya Khan", "12/01/1975", "Allahabad", 45),
            ("Aqeel Khan", "30/06/1956", "Kanpur", 50)]
df = pd.DataFrame(info, columns= ["Name", "DOB", "City", "Age"])

# %%
df
# Out:
#            Name         DOB       City  Age
# 0  Tanzeel Khan  05/05/2001     Kanpur   20
# 1   Khizra Khan  10'06'2002  Allahabad   19
# 2    Atiya Khan  12/01/1975  Allahabad   45
# 3    Aqeel Khan  30/06/1956     Kanpur   50

# %%
df[df.Age == df.Age.max()]
# Out:
#          Name         DOB    City  Age
# 3  Aqeel Khan  30/06/1956  Kanpur   50

# %%
df.Name[df.Age == df.Age.max()]
# Out:
# 3    Aqeel Khan
# Name: Name, dtype: object

# %%
g = df.groupby("City")

# %%
g.head()
# Out:
#            Name         DOB       City  Age
# 0  Tanzeel Khan  05/05/2001     Kanpur   20
# 1   Khizra Khan  10'06'2002  Allahabad   19
# 2    Atiya Khan  12/01/1975  Allahabad   45
# 3    Aqeel Khan  30/06/1956     Kanpur   50

# %%
for city, city_df in g:
  print(city)
  print(city_df)
# Out:
# Allahabad
#           Name         DOB       City  Age
# 1  Khizra Khan  10'06'2002  Allahabad   19
# 2   Atiya Khan  12/01/1975  Allahabad   45
# Kanpur
#            Name         DOB    City  Age
# 0  Tanzeel Khan  05/05/2001  Kanpur   20
# 3    Aqeel Khan  30/06/1956  Kanpur   50

# %%
x = g.get_group("Kanpur")

# %%
x
# Out:
#            Name         DOB    City  Age
# 0  Tanzeel Khan  05/05/2001  Kanpur   20
# 3    Aqeel Khan  30/06/1956  Kanpur   50

# %%
print(g.max())
# Out:
#                    Name         DOB  Age
# City
# Allahabad   Khizra Khan  12/01/1975   45
# Kanpur     Tanzeel Khan  30/06/1956   50

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/iris.csv")

# %%
data.shape
# Out:
# (150, 5)

# %%
data.plot.scatter("sepal_length", "sepal_width")

# %%
sns.set_style("whitegrid");
sns.FacetGrid(data, hue="species", size=4) \
 .map(plt.scatter, "sepal_length", "sepal_width") \
 .add_legend();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid")
sns.pairplot(data, hue="species", size=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(data, hue="species", size=10)  \
.map(sns.distplot, "petal_length") \
.add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
counts, bin_edges = np.histogram(data['petal_length'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)


counts, bin_edges = np.histogram(data['petal_length'], bins=20, 
                                 density = True)
pdf = counts/(sum(counts))
plt.plot(bin_edges[1:],pdf);

plt.show();
# Out:
# [0.24666667 0.08666667 0.         0.02       0.05333333 0.17333333
#  0.19333333 0.12       0.07333333 0.03333333]
# [1.   1.59 2.18 2.77 3.36 3.95 4.54 5.13 5.72 6.31 6.9 ]

# %%
print(np.mean(data["petal_length"]))
print(data["petal_length"].mean())
# Out:
# 3.7586666666666693
# 3.7586666666666693

# %%
print(np.percentile(data['petal_length'], np.arange(0, 100, 25)))
# Out:
# [1.   1.6  4.35 5.1 ]

# %%
sns.boxplot(x='species', y='petal_length', data=data)

# %%
sns.violinplot(x='species', y='petal_length', data=data, size = 10)

# %%
sns.jointplot(x="petal_length", y="petal_width", data = data, kind="kde")
